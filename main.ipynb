# %%
# Imports
import pandas as pd
import numpy as np
from sklearn.linear_model import LassoCV
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sb
# Load data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

y = np.log1p(train['SalePrice'])
test_ids = test['Id']
train.drop(['SalePrice', 'Id'], axis=1, inplace=True)
test.drop('Id', axis=1, inplace=True)


# Merge for feature engineering
all_data = pd.concat([train, test], axis=0)
#######Show empty data before#################
#sb.heatmap(all_data.isnull())
# Fill NA for categorical with 'None', for numeric with 0
for col in all_data.columns:
    if all_data[col].dtype == "object":
        all_data[col] = all_data[col].fillna("None")
    else:
        all_data[col] = all_data[col].fillna(0)

#######Show empty data after#################
#sb.heatmap(all_data.isnull())
# Encode categorical features
for col in all_data.select_dtypes('object').columns:
    all_data[col] = LabelEncoder().fit_transform(all_data[col])

# Feature engineering
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']
all_data['TotalBath'] = all_data['FullBath'] + 0.5 * all_data['HalfBath'] + all_data['BsmtFullBath'] + 0.5 * all_data['BsmtHalfBath']
all_data['Age'] = all_data['YrSold'] - all_data['YearBuilt']
all_data['RemodAge'] = all_data['YrSold'] - all_data['YearRemodAdd']
all_data['HasPool'] = (all_data['PoolArea'] > 0).astype(int)


# Final split
X_train = all_data.iloc[:train.shape[0], :]
X_test = all_data.iloc[train.shape[0]:, :]

# Cross-validation setup
kf = KFold(n_splits=5, shuffle=True, random_state=42)

#Regularization:
lasso = LassoCV(alphas=np.logspace(-4, -0.5, 30), cv=kf)
lasso.fit(X_train, y)
lasso_preds = lasso.predict(X_test)


# XGBoost
xgb_model = xgb.XGBRegressor(
    n_estimators=1000, learning_rate=0.01,
    max_depth=4, subsample=0.8, colsample_bytree=0.8,
    random_state=42
)
xgb_model.fit(X_train, y)
xgb_preds = xgb_model.predict(X_test)

# LightGBM
lgb_model = lgb.LGBMRegressor(
    n_estimators=1000, learning_rate=0.01,
    num_leaves=8, colsample_bytree=0.8, subsample=0.8,
    random_state=42
)
lgb_model.fit(X_train, y)
lgb_preds = lgb_model.predict(X_test)

# Blend predictions (weighted average)
my_model = (0.3 * lasso_preds) + (0.35 * xgb_preds) + (0.35 * lgb_preds)
final_preds = np.expm1(my_model)



###########for evaluating the model######################################3
# Split original training data for evaluation
X_train_eval, X_valid_eval, y_train_eval, y_valid_eval = train_test_split(
    X_train, y, test_size=0.2, random_state=42
)

# Fit models on train_eval and predict on valid_eval
# Lasso
lasso_eval = LassoCV(alphas=np.logspace(-4, -0.5, 30), cv=5)
lasso_eval.fit(X_train_eval, y_train_eval)
lasso_val_preds = lasso_eval.predict(X_valid_eval)

# XGBoost
xgb_eval = xgb.XGBRegressor(
    n_estimators=1000, learning_rate=0.01,
    max_depth=4, subsample=0.8, colsample_bytree=0.8,
    random_state=42
)
xgb_eval.fit(X_train_eval, y_train_eval)
xgb_val_preds = xgb_eval.predict(X_valid_eval)

# LightGBM
lgb_eval = lgb.LGBMRegressor(
    n_estimators=1000, learning_rate=0.01,
    num_leaves=8, colsample_bytree=0.8, subsample=0.8,
    random_state=42
)
lgb_eval.fit(X_train_eval, y_train_eval)
lgb_val_preds = lgb_eval.predict(X_valid_eval)

# Blend validation predictions
blended_val_preds = 0.3 * lasso_val_preds + 0.35 * xgb_val_preds + 0.35 * lgb_val_preds

# Evaluate
mse = mean_squared_error(y_valid_eval, blended_val_preds)
r2 = r2_score(y_valid_eval, blended_val_preds)

print(f"Validation MSE: {mse:.4f}")
print(f"Validation R² Score: {r2:.4f}")
# Out:
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07132011703066254, tolerance: 0.01780527646469407
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06545185024065603, tolerance: 0.01780527646469407
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7251912031613674, tolerance: 0.01780527646469407
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07238573888283639, tolerance: 0.01780527646469407
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07144390985580173, tolerance: 0.01780527646469407
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06609820627992136, tolerance: 0.01780527646469407
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05903811077226351, tolerance: 0.01780527646469407
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5357107184101082, tolerance: 0.01871197688547553
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8499013712446057, tolerance: 0.01871197688547553
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8086665084619096, tolerance: 0.01871197688547553
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7556219497764598, tolerance: 0.01871197688547553
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04023517024482004, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07363750795138202, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06402962263290846, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04783002772507672, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2335145646810979, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2066564452791013, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5991850004065853, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8040009154473822, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7694349102427651, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7169073345176216, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.34403884202520985, tolerance: 0.018106388734202852
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8728077207846638, tolerance: 0.019316247431817302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1900022791347311, tolerance: 0.019316247431817302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0888225829667224, tolerance: 0.019316247431817302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.353e+01, tolerance: 2.328e-02
#   model = cd_fast.enet_coordinate_descent(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002047 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3821
# [LightGBM] [Info] Number of data points in the train set: 1460, number of used features: 78
# [LightGBM] [Info] Start training from score 12.024057
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.057966867751954254, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.628937486172731, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6065357619819292, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7064656766944211, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07803796499340265, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3967243783583534, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3441268766233243, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2858612307367334, tolerance: 0.014284637439676189
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.053244483003112464, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05921960489398259, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5190948998975244, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.42613690035199, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3881716033390283, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3518734026946877, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4466664056395864, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4255264922619482, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3802360025512925, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3101563758430057, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2351981937650542, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1595328009805392, tolerance: 0.014355977611145281
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03187444894799185, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24330158021921733, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22951452855235388, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21717705665632892, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20674450772122555, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19890771542957175, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19229790757809795, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1870653953643675, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18286530242432164, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1794552719088358, tolerance: 0.013347420950409503
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.030081392697312026, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0374028964305424, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016321100089360385, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03983710204271418, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019995787702505652, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017507651644628197, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01578652024507221, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6382358280098135, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0599518550379674, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5532132811626465, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05805200236933672, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06121077937156372, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0579788451207115, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.052159046825494215, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04582010672331549, tolerance: 0.014396150959094158
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6332040065171061, tolerance: 0.01481515943147663
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027717575480039613, tolerance: 0.01481515943147663
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026183631052383305, tolerance: 0.01481515943147663
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02395258705491976, tolerance: 0.01481515943147663
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\owner\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.075e+00, tolerance: 1.781e-02
#   model = cd_fast.enet_coordinate_descent(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001975 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3555
# [LightGBM] [Info] Number of data points in the train set: 1168, number of used features: 77
# [LightGBM] [Info] Start training from score 12.030658
# Validation MSE: 0.0182
# Validation R² Score: 0.9027
